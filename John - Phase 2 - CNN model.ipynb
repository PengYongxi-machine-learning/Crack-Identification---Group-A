# %% [markdown]
# #### Modules

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from copy import deepcopy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import f1_score, recall_score

# Compatibility shim for imgaug on NumPy >= 2.0
if not hasattr(np, "sctypes"):
    np.sctypes = {"int": [np.int8, np.int16, np.int32, np.int64],
                  "uint": [np.uint8, np.uint16, np.uint32, np.uint64],
                  "float": [np.float16, np.float32, np.float64],
                  "complex": [np.complex64, np.complex128],
                  "others": [np.bool_, np.object_, np.str_, np.bytes_],}
import imgaug.augmenters as iaa

# %% [markdown]
# #### Use GPU for calculation
#
# Please use your GPU, do not wast your time on the stupid CPU

# %%
# Select device - supports NVIDIA CUDA, Apple Metal (M-chips), or CPU fallback
if torch.cuda.is_available():
    device = torch.device("cuda")
    device_type = "NVIDIA CUDA"
elif hasattr(torch.backends, 'mps') and torch.backends.mps.is_available() and torch.backends.mps.is_built():
    device = torch.device("mps")
    device_type = "Apple Metal (M-chip)"
else:
    device = torch.device("cpu")
    device_type = "CPU"

print(f"Using device: {device} ({device_type})")
# Out:
# Using device: cuda (NVIDIA CUDA)

# %% [markdown]
# #### Create more cracked samples using data augmentaion

# %%
# Data augmentation pipeline for crack samples (imgaug)
aug = iaa.Sequential([
    iaa.Affine(rotate=(-15, 15), shear=(-10, 10)),
    iaa.GaussianBlur(sigma=(0.1, 0.5)),
    iaa.Multiply((0.8, 1.2)),
    iaa.LinearContrast((0.8, 1.2)),
])

# Function to augment cracked samples
def augment_cracked_samples(df, num_augmentations=3):
    cracked = df[df['Label'] == 'Cracked'].copy()
    augmented_data = []

    for _, row in cracked.iterrows():
        img_array = np.asarray(row['ImageData'])
        orig_dtype = img_array.dtype

        # Keep augmentation in uint8 image space; normalization happens once in Dataset.
        if np.issubdtype(img_array.dtype, np.floating):
            max_val = float(np.max(img_array)) if img_array.size else 0.0
            input_is_unit_float = max_val <= 1.0
            if input_is_unit_float:
                img_u8 = (img_array * 255.0).clip(0, 255).astype(np.uint8)
            else:
                img_u8 = img_array.clip(0, 255).astype(np.uint8)
        else:
            input_is_unit_float = False
            img_u8 = img_array.clip(0, 255).astype(np.uint8)

        # imgaug expects (H, W, C) for multi-channel; keep grayscale compatible.
        if img_u8.ndim == 2:
            img_for_aug = img_u8[..., np.newaxis]
            squeeze_back = True
        else:
            img_for_aug = img_u8
            squeeze_back = False

        for i in range(num_augmentations):
            aug_img = aug(image=img_for_aug)
            if squeeze_back:
                aug_img = aug_img[..., 0]

            if np.issubdtype(orig_dtype, np.integer):
                aug_img = aug_img.astype(orig_dtype)
            else:
                aug_img = (aug_img.astype(np.float32) / 255.0) if input_is_unit_float else aug_img.astype(np.float32)

            augmented_data.append({
                "FileName": f"{row['FileName']}_aug_{i}",
                "Label": "Cracked",
                "ImageData": aug_img,})

    return pd.concat([df, pd.DataFrame(augmented_data)], ignore_index=True)

# %% [markdown]
# #### Train and testing splits
#
# Stratify ensures training, validation and testing datasets have the exact same proportion of crack and uncrack as the original dataset

# %%
# Load datasets
df_walls = pd.read_hdf('wall_data.h5', key='walls')
df_decks = pd.read_hdf('deck_data.h5', key='decks')
df_comb = pd.read_hdf('combined_data.h5', key='combined')

# Split the Walls DataFrame (15% of total data for validation, hence 0.15 / 0.80 = 0.1875 for second split)
walls, walls_te = train_test_split(df_walls, test_size=0.2, random_state=42, stratify=df_walls['Label'])
walls_tr, walls_val = train_test_split(walls, test_size=0.1875, random_state=42, stratify=walls['Label'])
walls_tr = augment_cracked_samples(walls_tr)

# Split the Decks DataFrame
decks, decks_te = train_test_split(df_decks, test_size=0.2, random_state=42, stratify=df_decks['Label'])
decks_tr, decks_val = train_test_split(decks, test_size=0.1875, random_state=42, stratify=decks['Label'])
decks_tr = augment_cracked_samples(decks_tr)

# Split the combined dataset into training, validation and testing sets
comb, comb_te = train_test_split(df_comb, test_size=0.2, random_state=42, stratify=df_comb['Label'])
comb_tr, comb_val = train_test_split(comb, test_size=0.1875, random_state=42, stratify=comb['Label'])
comb_tr = augment_cracked_samples(comb_tr)

# %% [markdown]
# #### CNN Architecture
#
# The network consists of 4 convolution layers and 3 hidden layers to be trained. The filters extract features in the image and pass the filter data to the neural network to perform classification.

# %%
class CNNBinary(nn.Module):
    def __init__(self):
        super().__init__()
        
        # Single-channel input for grayscale images
        self.features = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1, bias=False),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            
            nn.Conv2d(32, 64, kernel_size=3, padding=1, bias = False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            
            nn.Conv2d(64, 128, kernel_size=3, padding=1, bias = False),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2),
            
            nn.Conv2d(128, 256, kernel_size=3, padding=1, bias = False),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(2))

        # Replaced Flatten with AdaptiveAvgPool2d
        self.pool = nn.AdaptiveAvgPool2d((1, 1))
        
        self.classifier = nn.Sequential(
            nn.Flatten(),
            # Input is now just 256, drastically reducing parameters
            nn.Linear(256, 128), 
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(128, 64),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(64, 32),
            nn.ReLU(inplace=True),
            nn.Dropout(0.5),
            
            nn.Linear(32, 1))

    def forward(self, x):
        x = self.features(x)
        x = self.pool(x)       # Global Average Pooling
        x = self.classifier(x)
        return x


class EarlyStopping:
    def __init__(self, patience=5, min_delta=0.0):
        self.patience = patience
        self.min_delta = min_delta
        self.best_loss = float("inf")
        self.counter = 0
        self.best_state = None

    def __call__(self, val_loss, model):
        if val_loss < self.best_loss - self.min_delta:
            self.best_loss = val_loss
            self.counter = 0
            self.best_state = deepcopy(model.state_dict())
            return False

        self.counter += 1
        return self.counter >= self.patience

label_map = {'Non-Cracked': 0.0, 'Cracked': 1.0}

# %% [markdown]
# #### Data Generator (Memory Efficient)
#
# Instead of loading all images into memory at once, which causes the RAM TO EXPLODE, use a generator that loads images in batches to RAM during training.

# %%
# Custom PyTorch dataset (memory efficient)
class CrackDataset(Dataset):
    def __init__(self, dataframe, label_map):
        self.dataframe = dataframe.reset_index(drop=True)
        self.label_map = label_map

    def __len__(self):
        return len(self.dataframe)

    def __getitem__(self, idx):
        row = self.dataframe.iloc[idx]
        image = np.asarray(row['ImageData'], dtype=np.float32) / 255.0

        if image.ndim == 2:
            image = np.expand_dims(image, axis=0)
        elif image.ndim == 3:
            image = np.transpose(image, (2, 0, 1))
        else:
            raise ValueError(f"Unsupported image shape: {image.shape}")

        x = torch.from_numpy(image)
        y = torch.tensor(self.label_map[row['Label']], dtype=torch.float32)

        return x, y

# %% [markdown]
# #### Training phase
#
# 1. Use adam as gradient decent computation
#
# 2. First train on training dataset to optimize the parameters in filters and hidden layers
#
# 3. The criterion_loss is the POS Loss Function computed earlier, which is distinct for each dataset
#
# 4. Next, use validation set to track the training process so that the model is not over trained on too much epoch.
#
# 5. The early stop is going to stop the training once F1 score of the model cease to decrease after 5 epoches (controlled using patience)

# %%
model_walls = CNNBinary().to(device)
model_decks = CNNBinary().to(device)
model_comb = CNNBinary().to(device)

optimizer_walls = optim.Adam(model_walls.parameters(), lr=1e-4)
optimizer_decks = optim.Adam(model_decks.parameters(), lr=1e-4)
optimizer_comb = optim.Adam(model_comb.parameters(), lr=1e-4)

def train_model(model, train_loader, val_loader, optimizer, criterion_loss, device, epochs=300, patience=5, scheduler=None):
    
    # Early stopping based on F1 score instead of loss
    early_stopper = EarlyStopping(patience=patience)
    history = {"train_loss": [], "train_acc": [], "train_f1": [],
               "val_loss": [], "val_acc": [], "val_f1": [], "lr": []}
    best_f1_val = 0.0
    
    # Training phase
    for epoch in range(epochs):
        model.train()
        running_loss, correct, total = 0.0, 0, 0
        all_train_preds = []
        all_train_labels = []

        for images, labels in train_loader:
            images = images.to(device)
            labels = labels.to(device)
            # Compute loss function (logits is prediction probability, labels is ground truth) 
            optimizer.zero_grad()
            logits = model(images).squeeze(1)
            loss = criterion_loss(logits, labels)
            # Gradient backpropagation and optimization step
            loss.backward()
            # For MPS backend on Apple Silicon, use synchronize to ensure proper gradient updates
            if device.type == "mps":
                torch.mps.synchronize()
            # Use predicted probability (logits) to calculate training loss
            optimizer.step()
            running_loss += loss.item() * labels.size(0)
            # Use threshold of 0.5 to determine predicted class
            preds = (torch.sigmoid(logits) >= 0.5).float()
            # Predicted label compared to truth label for accuracy calculation
            correct += (preds == labels).sum().item()
            total += labels.size(0)
            # Store predictions and labels for metrics calculation
            all_train_preds.extend(preds.detach().cpu().numpy())
            all_train_labels.extend(labels.detach().cpu().numpy())

        train_loss = running_loss / total
        train_acc = correct / total
        train_f1 = f1_score(all_train_labels, all_train_preds, zero_division=0)
        train_recall = recall_score(all_train_labels, all_train_preds, zero_division=0)

        # Validation phase
        model.eval()
        val_running_loss, val_correct, val_total = 0.0, 0, 0
        all_val_preds = []
        all_val_labels = []

        with torch.no_grad():
            for images, labels in val_loader:
                images = images.to(device)
                labels = labels.to(device)
                # Use probability to calculate training loss (logits) and use threshold of 0.5 to determine predicted class
                logits = model(images).squeeze(1)
                loss = criterion_loss(logits, labels)
                # Assign prediction label based on predicted probability (logits) and threshold
                val_running_loss += loss.item() * labels.size(0)
                preds = (torch.sigmoid(logits) >= 0.5).float()
                val_correct += (preds == labels).sum().item()
                val_total += labels.size(0)
                # Store predictions and labels for metrics calculation
                all_val_preds.extend(preds.cpu().numpy())
                all_val_labels.extend(labels.cpu().numpy())

        # Calculate training validation metrics (loss, accuracy, F1 score)
        val_loss = val_running_loss / val_total
        val_acc = val_correct / val_total
        val_f1 = f1_score(all_val_labels, all_val_preds, zero_division=0)
        val_recall = recall_score(all_val_labels, all_val_preds, zero_division=0)
        
        if scheduler is not None:
            # ReduceLROnPlateau expects a monitored metric
            scheduler.step(val_f1)

        current_lr = optimizer.param_groups[0]['lr']
        history["train_loss"].append(train_loss)
        history["train_acc"].append(train_acc)
        history["train_f1"].append(train_f1)
        history["val_loss"].append(val_loss)
        history["val_acc"].append(val_acc)
        history["val_f1"].append(val_f1)
        history["lr"].append(current_lr)
        print(f"Epoch {epoch+1}/{epochs} - "
              f"train_loss: {train_loss:.4f}, train_f1: {train_f1:.4f}, train_recall:{train_recall:.4f} | "
              f"val_loss: {val_loss:.4f}, val_f1: {val_f1:.4f}, val_recall:{val_recall:.4f} | "
              f"lr: {current_lr:.6f}")

        # Early stopping based on F1 score
        if val_f1 > best_f1_val:
            best_f1_val = val_f1
            early_stopper.best_state = deepcopy(model.state_dict())
            early_stopper.counter = 0
        else:
            early_stopper.counter += 1
            if early_stopper.counter >= patience:
                print("Early stopping triggered (F1 score not improving).")
                break
        
    if early_stopper.best_state is not None:
        model.load_state_dict(early_stopper.best_state)

    return history

# %% [markdown]
# #### POS weight for loss function
#
# This is the weight assigned to each class in the loss function so that the penality for wrong prediction of minor class is more heavily penalize in the loss function. The value depends on the ratio between majority and minority

# %%
def calculate_pos_weight(dataframe, label_map):
    labels = dataframe['Label'].map(label_map).values
    num_neg = (labels == 0).sum()
    num_pos = (labels == 1).sum()
    if num_pos == 0:
        return torch.tensor(1.0)
    pos_weight = num_neg / num_pos
    return torch.tensor(pos_weight, dtype=torch.float32)

# %%
# Determine if pin_memory optimization can be used (only for CUDA)
pin_memory = torch.cuda.is_available()

# Create data loaders for Walls dataset (memory efficient)
train_ds_walls = CrackDataset(walls_tr, label_map)
val_ds_walls = CrackDataset(walls_val, label_map)
test_ds_walls = CrackDataset(walls_te, label_map)

# pos_weight for Walls training set
pos_weight_walls = calculate_pos_weight(walls_tr, label_map)
criterion_bce_weighted_walls = nn.BCEWithLogitsLoss(pos_weight=pos_weight_walls.to(device))
print(f"Walls pos_weight: {pos_weight_walls.item():.4f}")

# pin_memory optimization is specific to NVIDIA CUDA (not applicable to MPS or CPU)
train_loader_walls = DataLoader(train_ds_walls, batch_size=32, shuffle=True, num_workers=0, pin_memory=pin_memory)
val_loader_walls = DataLoader(val_ds_walls, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
test_loader_walls = DataLoader(test_ds_walls, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
# Out:
# Walls pos_weight: 0.9457

# %%
# Create data loaders for Decks dataset (memory efficient)
train_ds_decks = CrackDataset(decks_tr, label_map)
val_ds_decks = CrackDataset(decks_val, label_map)
test_ds_decks = CrackDataset(decks_te, label_map)

# pos_weight for Decks training set
pos_weight_decks = calculate_pos_weight(decks_tr, label_map)
criterion_bce_weighted_decks = nn.BCEWithLogitsLoss(pos_weight=pos_weight_decks.to(device))
print(f"Decks pos_weight: {pos_weight_decks.item():.4f}")

# pin_memory optimization is specific to NVIDIA CUDA (not applicable to MPS or CPU)
pin_memory = torch.cuda.is_available()
train_loader_decks = DataLoader(train_ds_decks, batch_size=32, shuffle=True, num_workers=0, pin_memory=pin_memory)
val_loader_decks = DataLoader(val_ds_decks, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
test_loader_decks = DataLoader(test_ds_decks, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
# Out:
# Decks pos_weight: 1.4918

# %%
# Create data loaders for Combined dataset (memory efficient)
train_ds_comb = CrackDataset(comb_tr, label_map)
val_ds_comb = CrackDataset(comb_val, label_map)
test_ds_comb = CrackDataset(comb_te, label_map)

# pos_weight for Combined training set
pos_weight_comb = calculate_pos_weight(comb_tr, label_map)
criterion_bce_weighted_comb = nn.BCEWithLogitsLoss(pos_weight=pos_weight_comb.to(device))
print(f"Combined pos_weight: {pos_weight_comb.item():.4f}")

# pin_memory optimization is specific to NVIDIA CUDA (not applicable to MPS or CPU)
pin_memory = torch.cuda.is_available()
train_loader_comb = DataLoader(train_ds_comb, batch_size=32, shuffle=True, num_workers=0, pin_memory=pin_memory)
val_loader_comb = DataLoader(val_ds_comb, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
test_loader_comb = DataLoader(test_ds_comb, batch_size=32, shuffle=False, num_workers=0, pin_memory=pin_memory)
# Out:
# Combined pos_weight: 1.1310

# %%
print("Wall ModelTraining with Weighted Loss (BCE with pos_weight)...\n")
scheduler_walls = optim.lr_scheduler.ReduceLROnPlateau(optimizer_walls, mode='max', factor=0.5, patience=2, min_lr=1e-6)

history_walls = train_model(
    model_walls,
    train_loader_walls,
    val_loader_walls,
    optimizer_walls,
    criterion_bce_weighted_walls,
    device,
    epochs=300,
    patience=5,
    scheduler=scheduler_walls)
# Out:
# Wall ModelTraining with Weighted Loss (BCE with pos_weight)...
#
# Epoch 1/300 - train_loss: 0.4066, train_f1: 0.8196, train_recall:0.7297 | val_loss: 0.4585, val_f1: 0.1405, val_recall:0.0764 | lr: 0.000100
# Epoch 2/300 - train_loss: 0.2918, train_f1: 0.8727, train_recall:0.7841 | val_loss: 0.4170, val_f1: 0.2849, val_recall:0.1705 | lr: 0.000100
# Epoch 3/300 - train_loss: 0.2722, train_f1: 0.8842, train_recall:0.8015 | val_loss: 0.4267, val_f1: 0.3995, val_recall:0.2806 | lr: 0.000100
# Epoch 4/300 - train_loss: 0.2605, train_f1: 0.8908, train_recall:0.8130 | val_loss: 0.3895, val_f1: 0.3800, val_recall:0.2362 | lr: 0.000100
# Epoch 5/300 - train_loss: 0.2519, train_f1: 0.8968, train_recall:0.8251 | val_loss: 0.3826, val_f1: 0.3983, val_recall:0.2522 | lr: 0.000100
# Epoch 6/300 - train_loss: 0.2382, train_f1: 0.9044, train_recall:0.8376 | val_loss: 0.3536, val_f1: 0.4901, val_recall:0.3286 | lr: 0.000100
# Epoch 7/300 - train_loss: 0.2374, train_f1: 0.9031, train_recall:0.8383 | val_loss: 0.3473, val_f1: 0.5078, val_recall:0.3481 | lr: 0.000100
# Epoch 8/300 - train_loss: 0.2236, train_f1: 0.9119, train_recall:0.8530 | val_loss: 0.3363, val_f1: 0.5162, val_recall:0.3535 | lr: 0.000100
# Epoch 9/300 - train_loss: 0.2151, train_f1: 0.9145, train_recall:0.8606 | val_loss: 0.3223, val_f1: 0.5457, val_recall:0.3819 | lr: 0.000100
# Epoch 10/300 - train_loss: 0.2089, train_f1: 0.9185, train_recall:0.8666 | val_loss: 0.3012, val_f1: 0.6409, val_recall:0.5151 | lr: 0.000100
# Epoch 11/300 - train_loss: 0.2058, train_f1: 0.9206, train_recall:0.8716 | val_loss: 0.3163, val_f1: 0.5757, val_recall:0.4121 | lr: 0.000100
# Epoch 12/300 - train_loss: 0.2020, train_f1: 0.9227, train_recall:0.8734 | val_loss: 0.2961, val_f1: 0.6382, val_recall:0.4920 | lr: 0.000100
# Epoch 13/300 - train_loss: 0.1975, train_f1: 0.9252, train_recall:0.8796 | val_loss: 0.3661, val_f1: 0.6415, val_recall:0.6199 | lr: 0.000100
# Epoch 14/300 - train_loss: 0.1943, train_f1: 0.9270, train_recall:0.8820 | val_loss: 0.2855, val_f1: 0.6512, val_recall:0.4991 | lr: 0.000100
# Epoch 15/300 - train_loss: 0.1886, train_f1: 0.9303, train_recall:0.8882 | val_loss: 0.2837, val_f1: 0.7089, val_recall:0.6465 | lr: 0.000100
# Epoch 16/300 - train_loss: 0.1836, train_f1: 0.9303, train_recall:0.8901 | val_loss: 0.2989, val_f1: 0.6605, val_recall:0.5062 | lr: 0.000100
# Epoch 17/300 - train_loss: 0.1837, train_f1: 0.9306, train_recall:0.8894 | val_loss: 0.2679, val_f1: 0.7162, val_recall:0.6075 | lr: 0.000100
# Epoch 18/300 - train_loss: 0.1779, train_f1: 0.9342, train_recall:0.8979 | val_loss: 0.2698, val_f1: 0.7144, val_recall:0.6110 | lr: 0.000100
# Epoch 19/300 - train_loss: 0.1733, train_f1: 0.9371, train_recall:0.9009 | val_loss: 0.2607, val_f1: 0.7269, val_recall:0.6288 | lr: 0.000100
# Epoch 20/300 - train_loss: 0.1704, train_f1: 0.9387, train_recall:0.9047 | val_loss: 0.2721, val_f1: 0.6893, val_recall:0.5400 | lr: 0.000100
# Epoch 21/300 - train_loss: 0.1705, train_f1: 0.9371, train_recall:0.9020 | val_loss: 0.2474, val_f1: 0.7532, val_recall:0.6750 | lr: 0.000100
# Epoch 22/300 - train_loss: 0.1663, train_f1: 0.9401, train_recall:0.9074 | val_loss: 0.2539, val_f1: 0.7544, val_recall:0.6927 | lr: 0.000100
# Epoch 23/300 - train_loss: 0.1630, train_f1: 0.9405, train_recall:0.9080 | val_loss: 0.2610, val_f1: 0.7146, val_recall:0.5915 | lr: 0.000100
# Epoch 24/300 - train_loss: 0.1585, train_f1: 0.9442, train_recall:0.9138 | val_loss: 0.2484, val_f1: 0.7302, val_recall:0.6057 | lr: 0.000100
# Epoch 25/300 - train_loss: 0.1552, train_f1: 0.9435, train_recall:0.9171 | val_loss: 0.2919, val_f1: 0.6689, val_recall:0.5240 | lr: 0.000050
# Epoch 26/300 - train_loss: 0.1505, train_f1: 0.9470, train_recall:0.9184 | val_loss: 0.2467, val_f1: 0.7607, val_recall:0.6607 | lr: 0.000050
# Epoch 27/300 - train_loss: 0.1461, train_f1: 0.9490, train_recall:0.9243 | val_loss: 0.2391, val_f1: 0.7743, val_recall:0.7069 | lr: 0.000050
# Epoch 28/300 - train_loss: 0.1401, train_f1: 0.9512, train_recall:0.9287 | val_loss: 0.2531, val_f1: 0.7505, val_recall:0.6625 | lr: 0.000050
# Epoch 29/300 - train_loss: 0.1380, train_f1: 0.9520, train_recall:0.9301 | val_loss: 0.2462, val_f1: 0.7604, val_recall:0.6625 | lr: 0.000050
# Epoch 30/300 - train_loss: 0.1375, train_f1: 0.9528, train_recall:0.9322 | val_loss: 0.2450, val_f1: 0.7609, val_recall:0.7460 | lr: 0.000025
# Epoch 31/300 - train_loss: 0.1297, train_f1: 0.9569, train_recall:0.9371 | val_loss: 0.2434, val_f1: 0.7685, val_recall:0.7549 | lr: 0.000025
# Epoch 32/300 - train_loss: 0.1261, train_f1: 0.9583, train_recall:0.9398 | val_loss: 0.2362, val_f1: 0.7785, val_recall:0.7336 | lr: 0.000025
# Epoch 33/300 - train_loss: 0.1232, train_f1: 0.9595, train_recall:0.9414 | val_loss: 0.2420, val_f1: 0.7625, val_recall:0.6785 | lr: 0.000025
# Epoch 34/300 - train_loss: 0.1212, train_f1: 0.9585, train_recall:0.9419 | val_loss: 0.2427, val_f1: 0.7769, val_recall:0.7300 | lr: 0.000025
# Epoch 35/300 - train_loss: 0.1242, train_f1: 0.9591, train_recall:0.9429 | val_loss: 0.2448, val_f1: 0.7690, val_recall:0.7567 | lr: 0.000013
# Epoch 36/300 - train_loss: 0.1172, train_f1: 0.9611, train_recall:0.9453 | val_loss: 0.2422, val_f1: 0.7750, val_recall:0.7282 | lr: 0.000013
# Epoch 37/300 - train_loss: 0.1158, train_f1: 0.9616, train_recall:0.9452 | val_loss: 0.2392, val_f1: 0.7797, val_recall:0.7229 | lr: 0.000013
# Epoch 38/300 - train_loss: 0.1139, train_f1: 0.9630, train_recall:0.9463 | val_loss: 0.2415, val_f1: 0.7782, val_recall:0.7229 | lr: 0.000013
# Epoch 39/300 - train_loss: 0.1141, train_f1: 0.9636, train_recall:0.9486 | val_loss: 0.2413, val_f1: 0.7704, val_recall:0.7300 | lr: 0.000013
# Epoch 40/300 - train_loss: 0.1103, train_f1: 0.9645, train_recall:0.9497 | val_loss: 0.2421, val_f1: 0.7813, val_recall:0.7425 | lr: 0.000013
# Epoch 41/300 - train_loss: 0.1103, train_f1: 0.9649, train_recall:0.9495 | val_loss: 0.2484, val_f1: 0.7737, val_recall:0.7105 | lr: 0.000013
# Epoch 42/300 - train_loss: 0.1105, train_f1: 0.9648, train_recall:0.9502 | val_loss: 0.2492, val_f1: 0.7767, val_recall:0.7229 | lr: 0.000013
# Epoch 43/300 - train_loss: 0.1115, train_f1: 0.9642, train_recall:0.9503 | val_loss: 0.2527, val_f1: 0.7718, val_recall:0.7389 | lr: 0.000006
# Epoch 44/300 - train_loss: 0.1082, train_f1: 0.9653, train_recall:0.9511 | val_loss: 0.2455, val_f1: 0.7733, val_recall:0.7300 | lr: 0.000006
# Epoch 45/300 - train_loss: 0.1065, train_f1: 0.9664, train_recall:0.9516 | val_loss: 0.2490, val_f1: 0.7762, val_recall:0.7300 | lr: 0.000006
# Early stopping triggered (F1 score not improving).

# %%
print("Deck ModelTraining with Weighted Loss (BCE with pos_weight)...\n")
scheduler_decks = optim.lr_scheduler.ReduceLROnPlateau(
    optimizer_decks, mode='max', factor=0.5, patience=2, min_lr=1e-6)

history_decks = train_model(
    model_decks,
    train_loader_decks,
    val_loader_decks,
    optimizer_decks,
    criterion_bce_weighted_decks,
    device,
    epochs=300,
    patience=5,
    scheduler=scheduler_decks)
# Out:
# Deck ModelTraining with Weighted Loss (BCE with pos_weight)...
#
# Epoch 1/300 - train_loss: 0.5659, train_f1: 0.7833, train_recall:0.7468 | val_loss: 0.4973, val_f1: 0.2269, val_recall:0.1315 | lr: 0.000100
# Epoch 2/300 - train_loss: 0.3863, train_f1: 0.8616, train_recall:0.7849 | val_loss: 0.4729, val_f1: 0.2588, val_recall:0.1522 | lr: 0.000100
# Epoch 3/300 - train_loss: 0.3714, train_f1: 0.8694, train_recall:0.7951 | val_loss: 0.4595, val_f1: 0.3958, val_recall:0.2595 | lr: 0.000100
# Epoch 4/300 - train_loss: 0.3577, train_f1: 0.8762, train_recall:0.8033 | val_loss: 0.4591, val_f1: 0.2907, val_recall:0.1730 | lr: 0.000100
# Epoch 5/300 - train_loss: 0.3428, train_f1: 0.8850, train_recall:0.8133 | val_loss: 0.4576, val_f1: 0.3191, val_recall:0.1938 | lr: 0.000100
# Epoch 6/300 - train_loss: 0.3410, train_f1: 0.8810, train_recall:0.8109 | val_loss: 0.4312, val_f1: 0.4523, val_recall:0.3114 | lr: 0.000100
# Epoch 7/300 - train_loss: 0.3283, train_f1: 0.8893, train_recall:0.8209 | val_loss: 0.4372, val_f1: 0.3815, val_recall:0.2422 | lr: 0.000100
# Epoch 8/300 - train_loss: 0.3271, train_f1: 0.8881, train_recall:0.8213 | val_loss: 0.4272, val_f1: 0.4541, val_recall:0.3080 | lr: 0.000100
# Epoch 9/300 - train_loss: 0.3239, train_f1: 0.8923, train_recall:0.8263 | val_loss: 0.4447, val_f1: 0.3662, val_recall:0.2249 | lr: 0.000100
# Epoch 10/300 - train_loss: 0.3161, train_f1: 0.8937, train_recall:0.8315 | val_loss: 0.4058, val_f1: 0.4988, val_recall:0.3564 | lr: 0.000100
# Epoch 11/300 - train_loss: 0.3076, train_f1: 0.8961, train_recall:0.8353 | val_loss: 0.4000, val_f1: 0.5024, val_recall:0.3564 | lr: 0.000100
# Epoch 12/300 - train_loss: 0.3031, train_f1: 0.8981, train_recall:0.8393 | val_loss: 0.3956, val_f1: 0.5251, val_recall:0.3806 | lr: 0.000100
# Epoch 13/300 - train_loss: 0.3030, train_f1: 0.8998, train_recall:0.8417 | val_loss: 0.3952, val_f1: 0.5374, val_recall:0.3979 | lr: 0.000100
# Epoch 14/300 - train_loss: 0.3001, train_f1: 0.9005, train_recall:0.8427 | val_loss: 0.4074, val_f1: 0.5232, val_recall:0.3702 | lr: 0.000100
# Epoch 15/300 - train_loss: 0.3018, train_f1: 0.8999, train_recall:0.8460 | val_loss: 0.4748, val_f1: 0.4545, val_recall:0.5017 | lr: 0.000100
# Epoch 16/300 - train_loss: 0.2950, train_f1: 0.9038, train_recall:0.8450 | val_loss: 0.3844, val_f1: 0.5635, val_recall:0.4221 | lr: 0.000100
# Epoch 17/300 - train_loss: 0.2894, train_f1: 0.9036, train_recall:0.8500 | val_loss: 0.3958, val_f1: 0.5113, val_recall:0.3529 | lr: 0.000100
# Epoch 18/300 - train_loss: 0.2869, train_f1: 0.9061, train_recall:0.8538 | val_loss: 0.3878, val_f1: 0.5592, val_recall:0.4083 | lr: 0.000100
# Epoch 19/300 - train_loss: 0.2819, train_f1: 0.9064, train_recall:0.8570 | val_loss: 0.3778, val_f1: 0.5818, val_recall:0.4429 | lr: 0.000100
# Epoch 20/300 - train_loss: 0.2749, train_f1: 0.9096, train_recall:0.8584 | val_loss: 0.4238, val_f1: 0.5279, val_recall:0.4740 | lr: 0.000100
# Epoch 21/300 - train_loss: 0.2708, train_f1: 0.9130, train_recall:0.8622 | val_loss: 0.3733, val_f1: 0.5979, val_recall:0.5017 | lr: 0.000100
# Epoch 22/300 - train_loss: 0.2654, train_f1: 0.9118, train_recall:0.8666 | val_loss: 0.3785, val_f1: 0.5477, val_recall:0.3875 | lr: 0.000100
# Epoch 23/300 - train_loss: 0.2669, train_f1: 0.9107, train_recall:0.8646 | val_loss: 0.3674, val_f1: 0.5952, val_recall:0.4706 | lr: 0.000100
# Epoch 24/300 - train_loss: 0.2612, train_f1: 0.9135, train_recall:0.8704 | val_loss: 0.3722, val_f1: 0.6063, val_recall:0.4637 | lr: 0.000100
# Epoch 25/300 - train_loss: 0.2569, train_f1: 0.9167, train_recall:0.8728 | val_loss: 0.3606, val_f1: 0.5988, val_recall:0.5190 | lr: 0.000100
# Epoch 26/300 - train_loss: 0.2570, train_f1: 0.9168, train_recall:0.8748 | val_loss: 0.3532, val_f1: 0.6266, val_recall:0.5225 | lr: 0.000100
# Epoch 27/300 - train_loss: 0.2508, train_f1: 0.9188, train_recall:0.8774 | val_loss: 0.3650, val_f1: 0.6062, val_recall:0.4740 | lr: 0.000100
# Epoch 28/300 - train_loss: 0.2484, train_f1: 0.9178, train_recall:0.8782 | val_loss: 0.3508, val_f1: 0.6176, val_recall:0.5087 | lr: 0.000100
# Epoch 29/300 - train_loss: 0.2452, train_f1: 0.9187, train_recall:0.8794 | val_loss: 0.3636, val_f1: 0.6049, val_recall:0.5087 | lr: 0.000050
# Epoch 30/300 - train_loss: 0.2361, train_f1: 0.9222, train_recall:0.8804 | val_loss: 0.3494, val_f1: 0.6164, val_recall:0.4671 | lr: 0.000050
# Epoch 31/300 - train_loss: 0.2302, train_f1: 0.9238, train_recall:0.8890 | val_loss: 0.3453, val_f1: 0.6304, val_recall:0.6021 | lr: 0.000050
# Epoch 32/300 - train_loss: 0.2341, train_f1: 0.9244, train_recall:0.8878 | val_loss: 0.3481, val_f1: 0.6085, val_recall:0.4706 | lr: 0.000050
# Epoch 33/300 - train_loss: 0.2270, train_f1: 0.9261, train_recall:0.8928 | val_loss: 0.3353, val_f1: 0.6505, val_recall:0.5571 | lr: 0.000050
# Epoch 34/300 - train_loss: 0.2214, train_f1: 0.9286, train_recall:0.8968 | val_loss: 0.3320, val_f1: 0.6426, val_recall:0.5536 | lr: 0.000050
# Epoch 35/300 - train_loss: 0.2339, train_f1: 0.9226, train_recall:0.8882 | val_loss: 0.3405, val_f1: 0.6398, val_recall:0.5225 | lr: 0.000050
# Epoch 36/300 - train_loss: 0.2256, train_f1: 0.9273, train_recall:0.8938 | val_loss: 0.3382, val_f1: 0.6531, val_recall:0.5536 | lr: 0.000050
# Epoch 37/300 - train_loss: 0.2211, train_f1: 0.9271, train_recall:0.8942 | val_loss: 0.3367, val_f1: 0.6214, val_recall:0.4913 | lr: 0.000050
# Epoch 38/300 - train_loss: 0.2168, train_f1: 0.9308, train_recall:0.9006 | val_loss: 0.3427, val_f1: 0.6365, val_recall:0.6090 | lr: 0.000050
# Epoch 39/300 - train_loss: 0.2137, train_f1: 0.9294, train_recall:0.8976 | val_loss: 0.3339, val_f1: 0.6245, val_recall:0.5121 | lr: 0.000025
# Epoch 40/300 - train_loss: 0.2038, train_f1: 0.9331, train_recall:0.9040 | val_loss: 0.3230, val_f1: 0.6653, val_recall:0.5744 | lr: 0.000025
# Epoch 41/300 - train_loss: 0.2073, train_f1: 0.9310, train_recall:0.8996 | val_loss: 0.3324, val_f1: 0.6424, val_recall:0.5502 | lr: 0.000025
# Epoch 42/300 - train_loss: 0.2028, train_f1: 0.9341, train_recall:0.9046 | val_loss: 0.3313, val_f1: 0.6513, val_recall:0.5848 | lr: 0.000025
# Epoch 43/300 - train_loss: 0.2002, train_f1: 0.9351, train_recall:0.9073 | val_loss: 0.3264, val_f1: 0.6601, val_recall:0.5813 | lr: 0.000013
# Epoch 44/300 - train_loss: 0.1958, train_f1: 0.9385, train_recall:0.9123 | val_loss: 0.3305, val_f1: 0.6448, val_recall:0.5779 | lr: 0.000013
# Epoch 45/300 - train_loss: 0.1959, train_f1: 0.9363, train_recall:0.9123 | val_loss: 0.3292, val_f1: 0.6641, val_recall:0.5882 | lr: 0.000013
# Early stopping triggered (F1 score not improving).

# %% [markdown]
# #### Evaluation Metrics - Recall, Precision, Confusion Matrix

# %%
# Function to evaluate model on test set and compute metrics (recall, precision, confusion matrix)
def evaluate_model(model, test_loader, device, threshold=0.5, dataset_name=""):
    # Evaluate model and compute recall, precision, confusion matrix
    model.eval()
    all_preds = []
    all_labels = []
    # Same logic as before to find the predicted label and acutal label
    # Use threshold to determine predicted class (0.5 is default for binary classification)
    with torch.no_grad():
        for images, labels in test_loader:
            images = images.to(device)
            labels = labels.to(device)
            logits = model(images).squeeze(1)
            preds = (torch.sigmoid(logits) >= threshold).float()
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    # Compute confusion matrix and show classification report (precision, recall, F1-score and etc)
    cm = confusion_matrix(all_labels, all_preds)
    report = classification_report(all_labels, all_preds, target_names=['Non-Cracked', 'Cracked'],output_dict=True)
    print(f"Test Set Evaluation - {dataset_name}")
    print(f"\nClassification Report:\n{classification_report(all_labels, all_preds, target_names=['Non-Cracked', 'Cracked'])}")
    
    # Visualize Confusion Matrix
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=True,
                xticklabels=['Predicted Non-Cracked', 'Predicted Cracked'],
                yticklabels=['Actual Non-Cracked', 'Actual Cracked'],
                annot_kws={'size': 12})
    plt.title(f'Confusion Matrix - {dataset_name}', fontsize=14, fontweight='bold')
    plt.ylabel('Actual Label', fontsize=12)
    plt.xlabel('Predicted Label', fontsize=12)
    plt.tight_layout()
    plt.show()
    return cm, report, all_preds, all_labels


# Evaluate both models on test sets(use threshold of 0.5 for initial evaluation)
cm_walls, report_walls, preds_walls, labels_walls = evaluate_model(model_walls, test_loader_walls, device, threshold=0.5, dataset_name="Walls Dataset")
cm_decks, report_decks, preds_decks, labels_decks = evaluate_model(model_decks, test_loader_decks, device, threshold=0.5, dataset_name="Decks Dataset")
# Out:
# Test Set Evaluation - Walls Dataset
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Cracked       0.93      0.97      0.95      2838
#      Cracked       0.85      0.74      0.79       750
#
#     accuracy                           0.92      3588
#    macro avg       0.89      0.85      0.87      3588
# weighted avg       0.92      0.92      0.92      3588
# Test Set Evaluation - Decks Dataset
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Cracked       0.93      0.97      0.95      2300
#      Cracked       0.80      0.59      0.68       385
#
#     accuracy                           0.92      2685
#    macro avg       0.87      0.78      0.82      2685
# weighted avg       0.91      0.92      0.91      2685

# %% [markdown]
# #### Threshold selction
#
# Select the threshold the maximize certain metric (F1 score or recall)

# %%
# Function to optimize threshold based on validation set performance (F1 score or recall)
def optimize_threshold(model, val_loader, device, metric='f1'):
    
    # The same logic as before to find out predicted label and true label on validation set
    model.eval()
    all_logits = []
    all_labels = []
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            logits = model(images).squeeze(1)
            all_logits.extend(torch.sigmoid(logits).cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    all_logits = np.array(all_logits)
    all_labels = np.array(all_labels)
    
    # Iterate through different thresholds to find the one that maximizes the specified metric (F1 score or recall)
    best_threshold = 0.5
    best_score = 0.0
    threshold_scores = []
    # Try different thresholds based on metric (F1 score or recall) and store the scores for each threshold
    for threshold in np.arange(0.1, 0.9, 0.01):
        preds = (all_logits >= threshold).astype(int)
        if metric == 'f1':
            score = f1_score(all_labels, preds, zero_division=0)
        elif metric == 'recall':
            score = recall_score(all_labels, preds, zero_division=0)
        threshold_scores.append((threshold, score))
        # Find the best threshold based that maximizes the specified metric
        if score > best_score:
            best_score = score
            best_threshold = threshold
    if metric == 'f1':
        print(f"Best Threshold (F1): {best_threshold:.3f} with F1 Score: {best_score:.4f}")
    elif metric == 'recall':
        print(f"Best Threshold (Recall): {best_threshold:.3f} with Recall: {best_score:.4f}")
    return best_threshold, best_score, threshold_scores


# Find optimal thresholds for both models (using validation set to avoid data leakage)
best_threshold_walls, best_f1_walls, scores_walls = optimize_threshold( model_walls, val_loader_walls, device, metric='recall')
best_threshold_decks, best_f1_decks, scores_decks = optimize_threshold( model_decks, val_loader_decks, device, metric='recall')
# Out:
# Best Threshold (Recall): 0.100 with Recall: 0.8401
# Best Threshold (Recall): 0.100 with Recall: 0.8581

# %% [markdown]
# #### Re-evaluate model performance on optimzied threshold

# %%
# Evaluate both models on test sets using optimal thresholds
cm_walls_opt, report_walls_opt, preds_walls_opt, labels_walls_opt = evaluate_model(
    model_walls, test_loader_walls, device, threshold=best_threshold_walls, dataset_name="Walls Dataset")

cm_decks_opt, report_decks_opt, preds_decks_opt, labels_decks_opt = evaluate_model(
    model_decks, test_loader_decks, device, threshold=best_threshold_decks, dataset_name="Decks Dataset")
# Out:
# Test Set Evaluation - Walls Dataset
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Cracked       0.96      0.88      0.91      2838
#      Cracked       0.64      0.84      0.73       750
#
#     accuracy                           0.87      3588
#    macro avg       0.80      0.86      0.82      3588
# weighted avg       0.89      0.87      0.88      3588
# Test Set Evaluation - Decks Dataset
#
# Classification Report:
#               precision    recall  f1-score   support
#
#  Non-Cracked       0.96      0.67      0.79      2300
#      Cracked       0.30      0.85      0.44       385
#
#     accuracy                           0.69      2685
#    macro avg       0.63      0.76      0.61      2685
# weighted avg       0.87      0.69      0.74      2685

# %% [markdown]
# #### Save models for phase 3, finding out shit images from dataset

# %%
# Save the trained models
torch.save(model_walls.state_dict(), 'model_walls.pth')
torch.save(model_decks.state_dict(), 'model_decks.pth')
